# %%
import warnings; warnings.simplefilter('ignore')
# Import relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_profiling as prof
import datetime as dt
import os
from fitter import Fitter
# %matplotlib inline

# %%
df.head()
# Out:
#    Store No       Order Id Order_date  Ship Date       Ship Mode Customer ID  \
# 0       762  CA-2014-44435 2014-05-11 2014-05-18  Standard Class    MD-17353
# 1       334  CA-2014-45259 2014-02-06 2014-02-13  Standard Class    JD-16165
# 2       543  CA-2014-45877 2014-05-29 2014-06-05     First Class    BS-11615
# 3       311  CA-2014-44933 2014-12-29 2015-01-05     First Class    SC-20735
# 4       762  CA-2014-45665 2014-12-27 2015-01-03     First Class    SV-20806
#
#        Customer Name      Segment        Country           City  ...   Region  \
# 0      Denise Monton  Home Office  United States  San Francisco  ...     West
# 1   Sean Christensen    Corporate  United States  San Francisco  ...     East
# 2     Robert Waldorf    Corporate  United States  San Francisco  ...  Central
# 3      Brendan Sweed  Home Office  United States  San Francisco  ...     East
# 4  Deborah Brumfield  Home Office  United States  San Francisco  ...  Central
#
#    Product ID Product SKU                Category  \
# 0       I-189       BV-23  Beverages: Fruit Based
# 1        I-67       BV-23  Chilled Dairy: Yoghurt
# 2        I-10       BV-23  Chilled Dairy: Yoghurt
# 3        I-89       BV-23  Beverages: Fruit Based
# 4       I-189       BV-23  Beverages: Fruit Based
#
#                   Sub-Category  \
# 0  Flavoured Sweet Fruit Juice
# 1          Flavoured Strawbery
# 2          Flavoured Strawbery
# 3  Flavoured Sweet Fruit Juice
# 4  Flavoured Sweet Fruit Juice
#
#                                         Product Name Brand Sales Review  \
# 0                      V8 Peach Mango, 46 oz. Bottle    V8  1563    158
# 1  GoGo Squeez Yogurtz Yogurt On The Go Strawberr...  GoGo  4392    143
# 2  GoGo Squeez Yogurtz Yogurt On The Go Strawberr...  GoGo  4852    188
# 3                      V8 Peach Mango, 46 oz. Bottle    V8  5415    194
# 4                      V8 Peach Mango, 46 oz. Bottle    V8  5178    168
#
#    price in $
# 0          22
# 1          25
# 2          24
# 3          24
# 4          22
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#           Store No   Postal Code        Sales       Review   price in $
# count  8760.000000   8760.000000  8760.000000  8760.000000  8760.000000
# mean    494.956279  60067.502397  2368.410046   302.859932    19.990068
# std     291.909079  28918.962190  1937.870770   206.723024     3.284440
# min     106.000000   1453.000000   100.000000    10.000000    15.000000
# 25%     237.000000  33614.000000   811.000000   103.000000    17.000000
# 50%     406.000000  60653.000000  1548.000000   300.000000    20.000000
# 75%     782.000000  90008.000000  4500.000000   503.000000    23.000000
# max     991.000000  98632.000000  6000.000000   600.000000    25.000000

# %%
df.nunique()
# Out:
# Store No           38
# Order Id         8760
# Order_date        365
# Ship Date         365
# Ship Mode           4
# Customer ID      7110
# Customer Name     480
# Segment             3
# Country             1
# City              222
# State               4
# Postal Code       147
# Region              3
# Product ID          5
# Product SKU         2
# Category            2
# Sub-Category        2
# Product Name        2
# Brand              72
# Sales            3351
# Review            392
# price in $         10
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 22 columns):
# Store No         8760 non-null int64
# Order Id         8760 non-null object
# Order_date       8760 non-null datetime64[ns]
# Ship Date        8760 non-null datetime64[ns]
# Ship Mode        8760 non-null object
# Customer ID      8760 non-null object
# Customer Name    6935 non-null object
# Segment          8760 non-null object
# Country          8760 non-null object
# City             8760 non-null object
# State            8760 non-null object
# Postal Code      8760 non-null int64
# Region           8760 non-null object
# Product ID       8760 non-null object
# Product SKU      8760 non-null object
# Category         8760 non-null object
# Sub-Category     8760 non-null object
# Product Name     7665 non-null object
# Brand            6206 non-null object
# Sales            8760 non-null int64
# Review           8760 non-null int64
# price in $       8760 non-null int64
# dtypes: datetime64[ns](2), int64(5), object(15)
# memory usage: 1.5+ MB

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')

# %%
df.head()
# Out:
#    store_no       order_id order_date  ship_date       ship_mode customer_id  \
# 0       762  CA-2014-44435 2014-05-11 2014-05-18  Standard Class    MD-17353
# 1       334  CA-2014-45259 2014-02-06 2014-02-13  Standard Class    JD-16165
# 2       543  CA-2014-45877 2014-05-29 2014-06-05     First Class    BS-11615
# 3       311  CA-2014-44933 2014-12-29 2015-01-05     First Class    SC-20735
# 4       762  CA-2014-45665 2014-12-27 2015-01-03     First Class    SV-20806
#
#        customer_name      segment        country           city  ...   region  \
# 0      Denise Monton  Home Office  United States  San Francisco  ...     West
# 1   Sean Christensen    Corporate  United States  San Francisco  ...     East
# 2     Robert Waldorf    Corporate  United States  San Francisco  ...  Central
# 3      Brendan Sweed  Home Office  United States  San Francisco  ...     East
# 4  Deborah Brumfield  Home Office  United States  San Francisco  ...  Central
#
#    product_id product_sku                category  \
# 0       I-189       BV-23  Beverages: Fruit Based
# 1        I-67       BV-23  Chilled Dairy: Yoghurt
# 2        I-10       BV-23  Chilled Dairy: Yoghurt
# 3        I-89       BV-23  Beverages: Fruit Based
# 4       I-189       BV-23  Beverages: Fruit Based
#
#                   sub-category  \
# 0  Flavoured Sweet Fruit Juice
# 1          Flavoured Strawbery
# 2          Flavoured Strawbery
# 3  Flavoured Sweet Fruit Juice
# 4  Flavoured Sweet Fruit Juice
#
#                                         product_name brand sales review  \
# 0                      V8 Peach Mango, 46 oz. Bottle    V8  1563    158
# 1  GoGo Squeez Yogurtz Yogurt On The Go Strawberr...  GoGo  4392    143
# 2  GoGo Squeez Yogurtz Yogurt On The Go Strawberr...  GoGo  4852    188
# 3                      V8 Peach Mango, 46 oz. Bottle    V8  5415    194
# 4                      V8 Peach Mango, 46 oz. Bottle    V8  5178    168
#
#    price_in_$
# 0          22
# 1          25
# 2          24
# 3          24
# 4          22
#
# [5 rows x 22 columns]

# %%
prof.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>22 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>8760 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>2.8% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.5 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>176.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>13 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_brand"><code>brand</code></a> has 2554 / 29.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_brand"><code>brand</code></a> has a high cardinality: 73 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_city"><code>city</code></a> has a high cardinality: 222 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_country"><code>country</code></a> has constant value United States <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_customer_id"><code>customer_id</code></a> has a high cardinality: 7110 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_customer_name"><code>customer_name</code></a> has 1825 / 20.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_customer_name"><code>customer_name</code></a> has a high cardinality: 481 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_product_name"><code>product_name</code></a> has 1095 / 12.5% missing values <span class="label label-default">Missing</span></li> </ul>
#     </div>
# </div>
#     <

# %%
iscp_report=prof.ProfileReport(df)

# %%
iscp_report.to_file()

# %%
corr = df.corr()

# %% [markdown]
# Store no and Postal code are not considerable
